# %% [markdown]
# Notebook prepared by Henrique Lopes Cardoso (hlc@fe.up.pt).
#
# # TEXT CLASSIFICATION

# %% [markdown]
# ## Original dataset
#
# For text classification, let's make use of a dataset of restaurant reviews, which can be used for a simple sentiment analysis task: each review is either positive (1) or negative (0).

# %%
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Restaurant_Reviews.tsv', delimiter = '\t', quoting = 3)

dataset.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %% [markdown]
# We can start by observing label distribution:

# %%
print(dataset['Liked'].value_counts())

print(dataset['Liked'].value_counts(normalize=True))

dataset['Liked'].value_counts().plot(kind='bar')
# Out:
# 1    500
# 0    500
# Name: Liked, dtype: int64
# 1    0.5
# 0    0.5
# Name: Liked, dtype: float64
# <AxesSubplot:>

# %% [markdown]
# ## Cleanup and normalization
#
# A typical first step when addressing text classification is to apply a few techniques to cleanup and normalize the text.
#
# We can start by quickly inspecting the contents of reviews. Print them all and try finding opportunities for cleanup and normalization operations.

# %%
pd.set_option('display.max_rows', 1000)
reviews = dataset["Review"]
print(reviews)
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
# 5         Now I am getting angry and I want my damn pho.
# 6                  Honeslty it didn't taste THAT fresh.)
# 7      The potatoes were like rubber and you could te...
# 8                              The fries were great too.
# 9                                         A great touch.
# 10                              Service was very prompt.
# 11                                    Would not go back.
# 12     The cashier had no care what so ever on what I...
# 13     I tried the Cape Cod ravoli, chicken, with cra...
# 14     I was disgusted because I was pretty sure that...
# 15     I was shocked because no signs indicate cash o...
# 16                                   Highly recommended.
# 17                Waitress was a little slow in service.
# 18     This place is not worth your time, let alone V...
# 19                                  did not like at all.
# 20                                   The Burrittos Blah!
# 21                                    The food, amazing.
# 22                                 Service is also cute.
# 23     I could care less... The interior is just beau...
# 24                                    So they performed.
# 25     That's right....the red velvet cake.....ohhh t...
# 26            - They never brought a salad we asked for.
# 27     This hole in the wall has great Mexican street...
# 28     Took an hour to get our food only 4 tables in ...
# 29                     The worst was the salmon sashimi.
# 30     Also there are combos like a burger, fries, an...
# 31                         This was like the final blow!
# 32     I found this place by accident and I could not...
# 33     seems like a good quick place to grab a bite o...
# 34                     Overall, I like this place a lot.
# 35     The only redeeming quality of the restaurant w...
# 36                       Ample portions and good prices.
# 37     Poor service, the waiter made me feel like I w...
# 38                 My first visit to Hiro was a delight!
# 39                                        Service sucks.
# 40                          The shrimp tender and moist.
# 41     There is not a deal good enough that would dra...
# 42     Hard to judge whether these sides were good be...
# 43     On a positive note, our server was very attent...
# 44     Frozen pucks of disgust, with some of the wors...
# 45     The only thing I did like was the prime rib an...
# 46             It's too bad the food is so damn generic.
# 47           The burger is good beef, cooked just right.
# 48     If you want a sandwich just go to any Firehous...
# 49     My side Greek salad with the Greek dressing wa...
# 50     We ordered the duck rare and it was pink and t...
# 51     He came running after us when he realized my h...
# 52                           Their chow mein is so good!
# 53     They have horrible attitudes towards customers...
# 54                                 The portion was huge!
# 55     Loved it...friendly servers, great food, wonde...
# 56     The Heart Attack Grill in downtown Vegas is an...
# 57     Not much seafood and like 5 strings of pasta a...
# 58     The salad had just the right amount of sauce t...
# 59     The ripped banana was not only ripped, but pet...
# 60     At least think to refill my water before I str...
# 61     This place receives stars for their APPETIZERS!!!
# 62         The cocktails are all handmade and delicious.
# 63                   We'd definitely go back here again.
# 64                   We are so glad we found this place.
# 65     Great food and service, huge portions and they...
# 66                   Always a great time at Dos Gringos!
# 67     Update.....went back for a second time and it ...
# 68     We got the food and apparently they have never...
# 69                        A great way to finish a great.
# 70     The deal included 5 tastings and 2 drinks, and...
# 71             - Really, really good rice, all the time.
# 72                                  The service was meh.
# 73     It took over 30 min to get their milkshake, wh...
# 74     I guess I should have known that this place wo...
# 75     The scallop dish is quite appalling for value ...
# 76                 2 times - Very Bad Customer Service !
# 77     The sweet potato fries were very good and seas...
# 78     Today is the second time I've been to their lu...
# 79     There is so much good food in Vegas that I fee...
# 80     Coming here is like experiencing an underwhelm...
# 81     walked in and the place smelled like an old gr...
# 82                 The turkey and roast beef were bland.
# 83                                    This place has it!
# 84     The pan cakes everyone are raving about taste ...
# 85     I love the Pho and the spring rolls oh so yumm...
# 86     The poor batter to meat ratio made the chicken...
# 87          All I have to say is the food was amazing!!!
# 88                               Omelets are to die for!
# 89                   Everything was fresh and delicious!
# 90     In summary, this was a largely disappointing d...
# 91     It's like a really sexy party in your mouth, w...
# 92     Never been to Hard Rock Casino before, WILL NE...
# 93                              Best breakfast buffet!!!
# 94                         say bye bye to your tip lady!
# 95                                 We'll never go again.
# 96                                   Will be back again!
# 97                                 Food arrived quickly!
# 98                                      It was not good.
# 99     On the up side, their cafe serves really good ...
# 100    Our server was fantastic and when he found out...
# 101    The only good thing was our waiter, he was ver...
# 102    Best Buffet in town, for the price you cannot ...
# 103    I LOVED their mussels cooked in this wine redu...
# 104    This is one of the better buffets that I have ...
# 105    So we went to Tigerlilly and had a fantastic a...
# 106    The food was delicious, our bartender was atte...
# 107    The ambience is wonderful and there is music p...
# 108                          Will go back next trip out.
# 109                                        Sooooo good!!
# 110    REAL sushi lovers, let's be honest - Yama is n...
# 111    At least 40min passed in between us ordering a...
# 112    This is a really fantastic Thai restaurant whi...
# 113                              Nice, spicy and tender.
# 114                                         Good prices.
# 115                                        Check it out.
# 116                                 It was pretty gross!
# 117                          I've had better atmosphere.
# 118        Kind of hard to mess up a steak but they did.
# 119    Although I very much liked the look and sound ...
# 120    I just don't know how this place managed to se...
# 121    Worst service to boot, but that is the least o...
# 122      Service was fine and the waitress was friendly.
# 123    The guys all had steaks, and our steak loving ...
# 124    We thought you'd have to venture further away ...
# 125    Host staff were, for lack of a better word, BI...
# 126    Bland... Not a liking this place for a number ...
# 127               Phenomenal food, service and ambiance.
# 128                                   I wouldn't return.
# 129    Definitely worth venturing off the strip for t...
# 130    This place is way too overpriced for mediocre ...
# 131                               Penne vodka excellent!
# 132    They have a good selection of food including a...
# 133                              The management is rude.
# 134    Delicious NYC bagels, good selections of cream...
# 135    Great Subway, in fact it's so good when you co...
# 136              I had a seriously solid breakfast here.
# 137     This is one of the best bars with food in Vegas.
# 138    He was extremely rude and really, there are so...
# 139    My drink was never empty and he made some real...
# 140                                      Don't do it!!!!
# 141    The waiter wasn't helpful or friendly and rare...
# 142    My husband and I ate lunch here and were very ...
# 143    And the red curry had so much bamboo shoots an...
# 144    Nice blanket of moz over top but i feel like t...
# 145    The bathrooms are clean and the place itself i...
# 146    The menu is always changing, food quality is g...
# 147    The service was a little slow , considering th...
# 148                              I give it 2 thumbs down
# 149    We watched our waiter pay a lot more attention...
# 150    My fiancé and I came in the middle of the day ...
# 151      This is a great restaurant at the Mandalay Bay.
# 152            We waited for forty five minutes in vain.
# 153         Crostini that came with the salad was stale.
# 154         Some highlights : Great quality nigiri here!
# 155    the staff is friendly and the joint is always ...
# 156    this was a different cut than the piece the ot...
# 157    I ordered the Voodoo pasta and it was the firs...
# 158                                  this place is good.
# 159    Unfortunately, we must have hit the bakery on ...
# 160    I came back today since they relocated and sti...
# 161                            I was seated immediately.
# 162        Their menu is diverse, and reasonably priced.
# 163                                   Avoid at all cost!
# 164          Restaurant is always full but never a wait.
# 165                                          DELICIOUS!!
# 166    This place is hands-down one of the best place...
# 167    So don't go there if you are looking for good ...
# 168                      I've never been treated so bad.
# 169                                Bacon is hella salty.
# 170    We also ordered the spinach and avocado salad,...
# 171    This really is how Vegas fine dining used to b...
# 172                    The waitresses are very friendly.
# 173    Lordy, the Khao Soi is a dish that is not to b...
# 174    Everything on the menu is terrific and we were...
# 175    Perhaps I caught them on an off night judging ...
# 176         The service here leaves a lot to be desired.
# 177    The atmosphere is modern and hip, while mainta...
# 178    Not a weekly haunt, but definitely a place to ...
# 179    We literally sat there for 20 minutes with no ...
# 180    The burger had absolutely no flavor - the meat...
# 181    I also decided not to send it back because our...
# 182                I dressed up to be treated so rudely!
# 183                                It was probably dirt.
# 184    Love this place, hits the spot when I want som...
# 185    I ordered the Lemon raspberry ice cocktail whi...
# 186    The food sucked, which we expected but it suck...
# 187                                   Interesting decor.
# 188       What I really like there is the crepe station.
# 189    Also were served hot bread and butter, and hom...
# 190    you can watch them preparing the delicious food!)
# 191                Both of the egg rolls were fantastic.
# 192    When my order arrived, one of the gyros was mi...
# 193    I had a salad with the wings, and some ice cre...
# 194    I'm not really sure how Joey's was voted best ...
# 195        The best place to go for a tasty bowl of Pho!
# 196             The live music on Fridays totally blows.
# 197    I've never been more insulted or felt disrespe...
# 198                                 Very friendly staff.
# 199                               It is worth the drive.
# 200    I had heard good things about this place, but ...
# 201               Food was great and so was the serivce!
# 202                           The warm beer didn't help.
# 203                                   Great brunch spot.
# 204                    Service is friendly and inviting.
# 205                                Very good lunch spot.
# 206    I've lived here since 1979 and this was the fi...
# 207                           The WORST EXPERIENCE EVER.
# 208           Must have been an off night at this place.
# 209    The sides are delish - mixed mushrooms, yukon ...
# 210    If that bug never showed up I would have given...
# 211    For about 10 minutes, we we're waiting for her...
# 212                   My friend loved the salmon tartar.
# 213                                       Won't go back.
# 214                                     Extremely Tasty!
# 215                            Waitress was good though!
# 216                                  Soggy and not good.
# 217                  The Jamaican mojitos are delicious.
# 218             Which are small and not worth the price.
# 219             - the food is rich so order accordingly.
# 220    The shower area is outside so you can only rin...
# 221                       The service was a bit lacking.
# 222    Lobster Bisque, Bussell Sprouts, Risotto, File...
# 223    Hopefully this bodes for them going out of bus...
# 224    It was either too cold, not enough flavor or j...
# 225                     I loved the bacon wrapped dates.
# 226                     This is an unbelievable BARGAIN!
# 227    The folks at Otto always make us feel so welco...
# 228                 As for the "mains," also uninspired.
# 229    This is the place where I first had pho and it...
# 230    This wonderful experience made this place a mu...
# 231    If the food isn't bad enough for you, then enj...
# 232                                  Very very fun chef.
# 233    Ordered a double cheeseburger & got a single p...
# 234    Great place to have a couple drinks and watch ...
# 235    If it were possible to give them zero stars, t...
# 236    The descriptions said "yum yum sauce" and anot...
# 237    I'd say that would be the hardest decision... ...
# 238    If she had not rolled the eyes we may have sta...
# 239    Everyone is very attentive, providing excellen...
# 240          Horrible - don't waste your time and money.
# 241                  Now this dish was quite flavourful.
# 242    By this time our side of the restaurant was al...
# 243    (It wasn't busy either) Also, the building was...
# 244    like the other reviewer said "you couldn't pay...
# 245    -Drinks took close to 30 minutes to come out a...
# 246                 Seriously flavorful delights, folks.
# 247    Much better than the other AYCE sushi place I ...
# 248    The lighting is just dark enough to set the mood.
# 249    Based on the sub-par service I received and no...
# 250                    Owner's are really great people.!
# 251    There is nothing privileged about working/eati...
# 252    The Greek dressing was very creamy and flavorful.
# 253    Overall, I don't think that I would take my pa...
# 254    Now the pizza itself was good the peanut sauce...
# 255    We had 7 at our table and the service was pret...
# 256                              Fantastic service here.
# 257    I as well would've given godfathers zero stars...
# 258                     They know how to make them here.
# 259                 very tough and very short on flavor!
# 260                     I hope this place sticks around.
# 261    I have been in more than a few bars in Vegas, ...
# 262             The restaurant atmosphere was exquisite.
# 263    Good service, very clean, and inexpensive, to ...
# 264       The seafood was fresh and generous in portion.
# 265                             Plus, it's only 8 bucks.
# 266               The service was not up to par, either.
# 267    Thus far, have only visited twice and the food...
# 268    Just as good as when I had it more than a year...
# 269    For a self proclaimed coffee cafe, I was wildl...
# 270        The Veggitarian platter is out of this world!
# 271         You cant go wrong with any of the food here.
# 272                                 You can't beat that.
# 273    Stopped by this place while in Madison for the...
# 274          The chefs were friendly and did a good job.
# 275    I've had better, not only from dedicated boba ...
# 276    I liked the patio and the service was outstand...
# 277    The goat taco didn't skimp on the meat and wow...
# 278                                    I think not again
# 279    I had the mac salad and it was pretty bland so...
# 280    I went to Bachi Burger on a friend's recommend...
# 281                                 Service stinks here!
# 282                                 I waited and waited.
# 283    This place is not quality sushi, it is not a q...
# 284    I would definitely recommend the wings as well...
# 285                              Great Pizza and Salads!
# 286    Things that went wrong: - They burned the saga...
# 287    We waited an hour for what was a breakfast I c...
# 288                               This place is amazing!
# 289    I hate to disagree with my fellow Yelpers, but...
# 290    Waited 2 hours & never got either of our pizza...
# 291               Just don't know why they were so slow.
# 292    The staff is great, the food is delish, and th...
# 293    I live in the neighborhood so I am disappointe...
# 294    I didn't know pulled pork could be soooo delic...
# 295    You get incredibly fresh fish, prepared with c...
# 296    Before I go in to why I gave a 1 star rating p...
# 297    I love the fact that everything on their menu ...
# 298          Never again will I be dining at this place!
# 299    The food was excellent and service was very good.
# 300    Good beer & drink selection and good food sele...
# 301    Please stay away from the shrimp stir fried no...
# 302    The potato chip order was sad... I could proba...
# 303                              Food was really boring.
# 304                                  Good Service-check!
# 305    This greedy corporation will NEVER see another...
# 306                            Will never, ever go back.
# 307    As much as I'd like to go back, I can't get pa...
# 308    In the summer, you can dine in a charming outd...
# 309                 I did not expect this to be so good!
# 310                                      Fantastic food!
# 311    She ordered a toasted English muffin that came...
# 312                              The food was very good.
# 313                                    Never going back.
# 314    Great food for the price, which is very high q...
# 315           The bus boy on the other hand was so rude.
# 316    By this point, my friends and I had basically ...
# 317    Back to good BBQ, lighter fare, reasonable pri...
# 318    And considering the two of us left there very ...
# 319                      All the bread is made in-house!
# 320                    The only downside is the service.
# 321    Also, the fries are without a doubt the worst ...
# 322    Service was exceptional and food was a good as...
# 323    A couple of months later, I returned and had a...
# 324       Favorite place in town for shawarrrrrrma!!!!!!
# 325    The black eyed peas and sweet potatoes... UNREAL!
# 326                           You won't be disappointed.
# 327    They could serve it with just the vinaigrette ...
# 328    I go to far too many places and I've never see...
# 329    When my mom and I got home she immediately got...
# 330    The servers are not pleasant to deal with and ...
# 331    Both of them were truly unbelievably good, and...
# 332    We had fantastic service, and were pleased by ...
# 333                                Everything was gross.
# 334                                   I love this place.
# 335                              Great service and food.
# 336    First - the bathrooms at this location were di...
# 337    The burger... I got the "Gold Standard" a $17 ...
# 338                         OMG, the food was delicioso!
# 339         There is nothing authentic about this place.
# 340         the spaghetti is nothing special whatsoever.
# 341    Of all the dishes, the salmon was the best, bu...
# 342    The vegetables are so fresh and the sauce feel...
# 343                   It's worth driving up from Tucson!
# 344    The selection was probably the worst I've seen...
# 345                      Pretty good beer selection too.
# 346             This place is like Chipotle, but BETTER.
# 347    Classy/warm atmosphere, fun and fresh appetize...
# 348                5 stars for the brick oven bread app!
# 349    I have eaten here multiple times, and each tim...
# 350    We sat another ten minutes and finally gave up...
# 351                                     He was terrible!
# 352                 Everyone is treated equally special.
# 353      It shouldn't take 30 min for pancakes and eggs.
# 354                                  It was delicious!!!
# 355    On the good side, the staff was genuinely plea...
# 356    Sadly, Gordon Ramsey's Steak is a place we sha...
# 357    As always the evening was wonderful and the fo...
# 358                  Best fish I've ever had in my life!
# 359      (The bathroom is just next door and very nice.)
# 360    The buffet is small and all the food they offe...
# 361    This is an Outstanding little restaurant with ...
# 362                             Pretty cool I would say.
# 363    Definitely a turn off for me & i doubt I'll be...
# 364    Server did a great job handling our large rowd...
# 365    I find wasting food to be despicable, but this...
# 366    My wife had the Lobster Bisque soup which was ...
# 367    Would come back again if I had a sushi craving...
# 368          The staff are great, the ambiance is great.
# 369                                 He deserves 5 stars.
# 370    I left with a stomach ache and felt sick the r...
# 371                     They dropped more than the ball.
# 372    The dining space is tiny, but elegantly decora...
# 373    They will customize your order any way you'd l...
# 374        And the beans and rice were mediocre at best.
# 375                          Best tacos in town by far!!
# 376            I took back my money and got outta there.
# 377    In an interesting part of town, this place is ...
# 378                     RUDE & INCONSIDERATE MANAGEMENT.
# 379    The staff are now not as friendly, the wait ti...
# 380                                     I won't be back.
# 381                             They have great dinners.
# 382    The service was outshining & I definitely reco...
# 383                               The food was terrible.
# 384    WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEO...
# 385    I don't recommend unless your car breaks down ...
# 386       I will come back here every time I'm in Vegas.
# 387    This place deserves one star and 90% has to do...
# 388                                  This is a disgrace.
# 389                    Def coming back to bowl next time
# 390    If you want healthy authentic or ethic food, t...
# 391    I will continue to come here on ladies night a...
# 392    I have been here several times in the past, an...
# 393    We walked away stuffed and happy about our fir...
# 394    Service was excellent and prices are pretty re...
# 395    To summarize... the food was incredible, nay, ...
# 396    I'm probably one of the few people to ever go ...
# 397    Kids pizza is always a hit too with lots of gr...
# 398    Service is perfect and the family atmosphere i...
# 399    Cooked to perfection and the service was impec...
# 400                 This one is simply a disappointment.
# 401    Overall, I was very disappointed with the qual...
# 402    I don't have to be an accountant to know I'm g...
# 403    Great place to eat, reminds me of the little m...
# 404    Today was my first taste of a Buldogis Gourmet...
# 405                                Left very frustrated.
# 406                    I'll definitely be in soon again.
# 407      Food was really good and I got full petty fast.
# 408                               Service was fantastic.
# 409                                 TOTAL WASTE OF TIME.
# 410    I don't know what kind it is but they have the...
# 411                Come hungry, leave happy and stuffed!
# 412                   For service, I give them no stars.
# 413     I can assure you that you won't be disappointed.
# 414    I can take a little bad service but the food s...
# 415    Gave up trying to eat any of the crust (teeth ...
# 416                But now I was completely grossed out.
# 417                        I really enjoyed eating here.
# 418    First time going but I think I will quickly be...
# 419    Our server was very nice, and even though he l...
# 420    From what my dinner companions told me...every...
# 421    On the ground, right next to our table was a l...
# 422    Furthermore, you can't even find hours of oper...
# 423    We've tried to like this place but after 10+ t...
# 424                             What a mistake that was!
# 425                                       No complaints!
# 426    This is some seriously good pizza and I'm an e...
# 427                                   Waiter was a jerk.
# 428                    Strike 2, who wants to be rushed.
# 429    These are the nicest restaurant owners I've ev...
# 430                                  I never come again.
# 431                             We loved the biscuits!!!
# 432                       Service is quick and friendly.
# 433    Ordered an appetizer and took 40 minutes and t...
# 434                             So absolutley fantastic.
# 435    It was a huge awkward 1.5lb piece of cow that ...
# 436                definitely will come back here again.
# 437    I like Steiners because it's dark and it feels...
# 438                        Wow very spicy but delicious.
# 439                If you're not familiar, check it out.
# 440      I'll take my business dinner dollars elsewhere.
# 441                                 I'd love to go back.
# 442    Anyway, this FS restaurant has a wonderful bre...
# 443                                     Nothing special.
# 444    Each day of the week they have a different dea...
# 445    Not to mention the combination of pears, almon...
# 446                                    Will not be back.
# 447                                 Sauce was tasteless.
# 448    The food is delicious and just spicy enough, s...
# 449    My ribeye steak was cooked perfectly and had g...
# 450      I don't think we'll be going back anytime soon.
# 451                                  Food was so gooodd.
# 452    I am far from a sushi connoisseur but I can de...
# 453                                   I was so insulted.
# 454      The last 3 times I had lunch here has been bad.
# 455    The chicken wings contained the driest chicken...
# 456    The food was very good and I enjoyed every mou...
# 457                     Nargile - I think you are great.
# 458                    Best tater tots in the southwest.
# 459                                  We loved the place.
# 460                  Definitely not worth the $3 I paid.
# 461    The vanilla ice cream was creamy and smooth wh...
# 462      Im in AZ all the time and now have my new spot.
# 463                           The manager was the worst.
# 464      The inside is really quite nice and very clean.
# 465    The food was outstanding and the prices were v...
# 466    I don't think I'll be running back to Carly's ...
# 467    This is was due to the fact that it took 20 mi...
# 468                            Love the margaritas, too!
# 469    This was my first and only Vegas buffet and it...
# 470                                   Very good, though!
# 471    The one down note is the ventilation could use...
# 472                                 Great pork sandwich.
# 473                          Don't waste your time here.
# 474    Total letdown, I would much rather just go to ...
# 475    Third, the cheese on my friend's burger was cold.
# 476                     We enjoy their pizza and brunch.
# 477    The steaks are all well trimmed and also perfe...
# 478    We had a group of 70+ when we claimed we would...
# 479                                          I LOVED it!
# 480    We asked for the bill to leave without eating ...
# 481    This place is a jewel in Las Vegas, and exactl...
# 482    Seafood was limited to boiled shrimp and crab ...
# 483              The selection of food was not the best.
# 484             Delicious and I will absolutely be back!
# 485    This isn't a small family restaurant, this is ...
# 486    They had a toro tartare with a cavier that was...
# 487    I dont think I will be back for a very long time.
# 488    It was attached to a gas station, and that is ...
# 489                                 How awesome is that.
# 490                      I will be back many times soon.
# 491    The menu had so much good stuff on it i could ...
# 492    Worse of all, he humiliated his worker right i...
# 493                      CONCLUSION: Very filling meals.
# 494    Their daily specials are always a hit with my ...
# 495                             And then tragedy struck.
# 496    The pancake was also really good and pretty la...
# 497    This was my first crawfish experience, and it ...
# 498    Their monster chicken fried steak and eggs is ...
# 499                        Waitress was sweet and funny.
# 500    I also had to taste my Mom's multi-grain pumpk...
# 501              I'd rather eat airline food, seriously.
# 502        Cant say enough good things about this place.
# 503                         The ambiance was incredible.
# 504            The waitress and manager are so friendly.
# 505                    I would not recommend this place.
# 506           Overall I wasn't very impressed with Noca.
# 507                  My gyro was basically lettuce only.
# 508                                    Terrible service!
# 509                             Thoroughly disappointed!
# 510    I don't each much pasta, but I love the homema...
# 511            Give it a try, you will be happy you did.
# 512        By far the BEST cheesecurds we have ever had!
# 513                              Reasonably priced also!
# 514         Everything was perfect the night we were in.
# 515     The food is very good for your typical bar food.
# 516                         it was a drive to get there.
# 517    At first glance it is a lovely bakery cafe - n...
# 518         Anyway, I do not think i will go back there.
# 519    Point your finger at any item on the menu, ord...
# 520    Oh this is such a thing of beauty, this restau...
# 521                     If you haven't gone here GO NOW!
# 522                            A greasy, unhealthy meal.
# 523         first time there and might just be the last.
# 524                          Those burgers were amazing.
# 525    Similarly, the delivery man did not say a word...
# 526                         And it was way to expensive.
# 527    Be sure to order dessert, even if you need to ...
# 528    This was my first time and I can't wait until ...
# 529                         The bartender was also nice.
# 530                       Everything was good and tasty!
# 531               This place is two thumbs up....way up.
# 532    The best place in Vegas for breakfast (just ch...
# 533    If you love authentic Mexican food and want a ...
# 534                                 Terrible management.
# 535    An excellent new restaurant by an experienced ...
# 536    If there were zero stars I would give it zero ...
# 537    Great steak, great sides, great wine, amazing ...
# 538                                  Worst martini ever!
# 539    The steak and the shrimp are in my opinion the...
# 540    I had the opportunity today to sample your ama...
# 541    We waited for thirty minutes to be seated (alt...
# 542    The yellowtail carpaccio was melt in your mout...
# 543     I won't try going back there even if it's empty.
# 544    No, I'm going to eat the potato that I found s...
# 545                Just spicy enough.. Perfect actually.
# 546    Last night was my second time dining here and ...
# 547       not even a "hello, we will be right with you."
# 548                     The desserts were a bit strange.
# 549    My boyfriend and I came here for the first tim...
# 550    I really do recommend this place, you can go w...
# 551                                       Nice ambiance.
# 552              I would recommend saving room for this!
# 553    I guess maybe we went on an off night but it w...
# 554    However, my recent experience at this particul...
# 555    I know this is not like the other restaurants ...
# 556                            AVOID THIS ESTABLISHMENT!
# 557    I think this restaurant suffers from not tryin...
# 558              All of the tapas dishes were delicious!
# 559                                I *heart* this place.
# 560    My salad had a bland vinegrette on the baby gr...
# 561                         After two I felt disgusting.
# 562                                         A good time!
# 563    I believe that this place is a great stop for ...
# 564                   Generous portions and great taste.
# 565    I will never go back to this place and will ne...
# 566    The servers went back and forth several times,...
# 567                                  Food was delicious!
# 568                                AN HOUR... seriously?
# 569                               I consider this theft.
# 570      Eew... This location needs a complete overhaul.
# 571    We recently witnessed her poor quality of mana...
# 572                        Waited and waited and waited.
# 573    He also came back to check on us regularly, ex...
# 574    Our server was super nice and checked on us ma...
# 575    The pizza tasted old, super chewy in not a goo...
# 576    I swung in to give them a try but was deeply d...
# 577         Service was good and the company was better!
# 578      The staff are also very friendly and efficient.
# 579    As for the service: I'm a fan, because it's qu...
# 580                           Boy was that sucker dry!!.
# 581                                          Over rated.
# 582    If you look for authentic Thai food, go else w...
# 583                   Their steaks are 100% recommended!
# 584    After I pulled up my car I waited for another ...
# 585    Great food and great service in a clean and fr...
# 586           All in all, I can assure you I'll be back.
# 587    I hate those things as much as cheap quality b...
# 588    My breakfast was perpared great, with a beauti...
# 589                         The kids play area is NASTY!
# 590                   Great place fo take out or eat in.
# 591    The waitress was friendly and happy to accomod...
# 592    OMG I felt like I had never eaten Thai food un...
# 593      It was extremely "crumby" and pretty tasteless.
# 594    It was a pale color instead of nice and char a...
# 595    The croutons also taste homemade which is an e...
# 596        I got home to see the driest damn wings ever!
# 597      It'll be a regular stop on my trips to Phoenix!
# 598    I really enjoyed Crema Café before they expand...
# 599                              Not good for the money.
# 600     I miss it and wish they had one in Philadelphia!
# 601    We got sitting fairly fast, but, ended up wait...
# 602        They also have the best cheese crisp in town.
# 603               Good value, great food, great service.
# 604             Couldn't ask for a more satisfying meal.
# 605                                    The food is good.
# 606                                      It was awesome.
# 607                              I just wanted to leave.
# 608    We made the drive all the way from North Scott...
# 609                    I will not be eating there again.
# 610    !....THE OWNERS REALLY REALLY need to quit bei...
# 611    I checked out this place a couple years ago an...
# 612    The chicken I got was definitely reheated and ...
# 613    Sorry, I will not be getting food from here an...
# 614                              An absolute must visit!
# 615          The cow tongue and cheek tacos are amazing.
# 616              My friend did not like his Bloody Mary.
# 617    Despite how hard I rate businesses, its actual...
# 618    They really want to make your experience a goo...
# 619                                   I will not return.
# 620      I had the chicken Pho and it tasted very bland.
# 621                                Very disappointing!!!
# 622    The grilled chicken was so tender and yellow f...
# 623    a drive thru means you do not want to wait aro...
# 624                                Pretty awesome place.
# 625                                 Ambience is perfect.
# 626    Best of luck to the rude and non-customer serv...
# 627    Any grandmother can make a roasted chicken bet...
# 628    I asked multiple times for the wine list and a...
# 629    The staff is always super friendly and helpful...
# 630    Four stars for the food & the guy in the blue ...
# 631          The roast beef sandwich tasted really good!
# 632    Same evening, him and I are both drastically s...
# 633    High-quality chicken on the chicken Caesar salad.
# 634              Ordered burger rare came in we'll done.
# 635                 We were promptly greeted and seated.
# 636    Tried to go here for lunch and it was a madhouse.
# 637    I was proven dead wrong by this sushi bar, not...
# 638    After waiting an hour and being seated, I was ...
# 639                                This is a good joint.
# 640                 The Macarons here are insanely good.
# 641                                 I'm not eating here!
# 642    Our waiter was very attentive, friendly, and i...
# 643    Maybe if they weren't cold they would have bee...
# 644    This place has a lot of promise but fails to d...
# 645                                 Very bad Experience!
# 646                                      What a mistake.
# 647                            Food was average at best.
# 648                                          Great food.
# 649                 We won't be going back anytime soon!
# 650    Very Very Disappointed ordered the $35 Big Bay...
# 651    Great place to relax and have an awesome burge...
# 652    It is PERFECT for a sit-down family meal or ge...
# 653    Not much flavor to them, and very poorly const...
# 654              The patio seating was very comfortable.
# 655                      The fried rice was dry as well.
# 656           Hands down my favorite Italian restaurant!
# 657    That just SCREAMS "LEGIT" in my book...sometha...
# 658                    It was just not a fun experience.
# 659    The atmosphere was great with a lovely duo of ...
# 660    I personally love the hummus, pita, baklava, f...
# 661    Very convenient, since we were staying at the ...
# 662    The owners are super friendly and the staff is...
# 663                                          Both great!
# 664                                  Eclectic selection.
# 665    The sweet potato tots were good but the onion ...
# 666                        The staff was very attentive.
# 667    And the chef was generous with his time (even ...
# 668    The owner used to work at Nobu, so this place ...
# 669    Google mediocre and I imagine Smashburger will...
# 670                                        dont go here.
# 671                     I promise they won't disappoint.
# 672      As a sushi lover avoid this place by all means.
# 673                    What a great double cheeseburger!
# 674                            Awesome service and food.
# 675                     A fantastic neighborhood gem !!!
# 676                             I can't wait to go back.
# 677       The plantains were the worst I've ever tasted.
# 678        It's a great place and I highly recommend it.
# 679                  Service was slow and not attentive.
# 680    I gave it 5 stars then, and I'm giving it 5 st...
# 681    Your staff spends more time talking to themsel...
# 682                    Dessert: Panna Cotta was amazing.
# 683                   Very good food, great atmosphere.1
# 684                                     Damn good steak.
# 685                                   Total brunch fail.
# 686    Prices are very reasonable, flavors are spot o...
# 687    The decor is nice, and the piano music soundtr...
# 688    The steak was amazing...rge fillet relleno was...
# 689                           Good food , good service .
# 690                           It was absolutely amazing.
# 691              I probably won't be back, to be honest.
# 692                             will definitely be back!
# 693    The sergeant pepper beef sandwich with auju sa...
# 694    Hawaiian Breeze, Mango Magic, and Pineapple De...
# 695                   Went for lunch - service was slow.
# 696    We had so much to say about the place before w...
# 697                                     I was mortified.
# 698    Needless to say, we will never be back here ag...
# 699    Anyways, The food was definitely not filling a...
# 700    The chips that came out were dripping with gre...
# 701          I wasn't really impressed with Strip Steak.
# 702    Have been going since 2007 and every meal has ...
# 703    Our server was very nice and attentive as were...
# 704    The cashier was friendly and even brought the ...
# 705    I work in the hospitality industry in Paradise...
# 706                          The atmosphere here is fun.
# 707                       Would not recommend to others.
# 708    Service is quick and even "to go" orders are j...
# 709    I mean really, how do you get so famous for yo...
# 710    That said, our mouths and bellies were still q...
# 711                                        Not my thing.
# 712                                        2 Thumbs Up!!
# 713       If you are reading this please don't go there.
# 714    I loved the grilled pizza, reminded me of legi...
# 715    Only Pros : Large seating area/ Nice bar area/...
# 716                  They have a really nice atmosphere.
# 717    Tonight I had the Elk Filet special...and it s...
# 718                        After one bite, I was hooked.
# 719    We ordered some old classics and some new dish...
# 720                        Cute, quaint, simple, honest.
# 721    The chicken was deliciously seasoned and had t...
# 722    The food was great as always, compliments to t...
# 723    Special thanks to Dylan T. for the recommendat...
# 724                           Awesome selection of beer.
# 725                      Great food and awesome service!
# 726    One nice thing was that they added gratuity on...
# 727          A FLY was in my apple juice.. A FLY!!!!!!!!
# 728             The Han Nan Chicken was also very tasty.
# 729           As for the service, I thought it was good.
# 730    The food was barely lukewarm, so it must have ...
# 731    Ryan's Bar is definitely one Edinburgh establi...
# 732      Nicest Chinese restaurant I've been in a while.
# 733          Overall, I like there food and the service.
# 734    They also now serve Indian naan bread with hum...
# 735    Probably never coming back, and wouldn't recom...
# 736    Friend's pasta -- also bad, he barely touched it.
# 737    Try them in the airport to experience some tas...
# 738    I love the decor with the Chinese calligraphy ...
# 739           Never had anything to complain about here.
# 740    The restaurant is very clean and has a family ...
# 741                               It was way over fried.
# 742    I'm not sure how long we stood there but it wa...
# 743    When I opened the sandwich, I was impressed, b...
# 744                                    Will not be back!
# 745    There was a warm feeling with the service and ...
# 746    An extensive menu provides lots of options for...
# 747    I always order from the vegetarian menu during...
# 748    I have watched their prices inflate, portions ...
# 749    Wonderful lil tapas and the ambience made me f...
# 750    I got to enjoy the seafood salad, with a fabul...
# 751    The wontons were thin, not thick and chewy, al...
# 752    Level 5 spicy was perfect, where spice didn't ...
# 753    We were sat right on time and our server from ...
# 754    Main thing I didn't enjoy is that the crowd is...
# 755    When I'm on this side of town, this will defin...
# 756    I had to wait over 30 minutes to get my drink ...
# 757                        This is a GREAT place to eat!
# 758                    The jalapeno bacon is soooo good.
# 759           The service was poor and thats being nice.
# 760    Food was good, service was good, Prices were g...
# 761    The place was not clean and the food oh so stale!
# 762    The chicken dishes are OK, the beef is like sh...
# 763                      But the service was beyond bad.
# 764                          I'm so happy to be here!!!"
# 765                                    Tasted like dirt.
# 766    One of the few places in Phoenix that I would ...
# 767                               The block was amazing.
# 768    It's close to my house, it's low-key, non-fanc...
# 769    * Both the Hot & Sour & the Egg Flower Soups w...
# 770    My sashimi was poor quality being soggy and ta...
# 771        Great time - family dinner on a Sunday night.
# 772    the food is not tasty at all, not to say its "...
# 773            What did bother me, was the slow service.
# 774         The flair bartenders are absolutely amazing!
# 775    Their frozen margaritas are WAY too sugary for...
# 776            These were so good we ordered them twice.
# 777    So in a nutshell: 1) The restaraunt smells lik...
# 778                   My girlfriend's veal was very bad.
# 779                      Unfortunately, it was not good.
# 780                 I had a pretty satifying experience.
# 781      Join the club and get awesome offers via email.
# 782    Perfect for someone (me) who only likes beer i...
# 783    Bland and flavorless is a good way of describi...
# 784    The chains, which I'm no fan of, beat this pla...
# 785                          The nachos are a MUST HAVE!
# 786                          We will not be coming back.
# 787    I don't have very many words to say about this...
# 788    The staff is super nice and very quick even wi...
# 789         Great atmosphere, friendly and fast service.
# 790    When I received my Pita it was huge it did hav...
# 791                     Once your food arrives it's meh.
# 792    Paying $7.85 for a hot dog and fries that look...
# 793        The classic Maine Lobster Roll was fantastic.
# 794    My brother in law who works at the mall ate he...
# 795    So good I am going to have to review this plac...
# 796    The chips and salsa were really good, the sals...
# 797                    This place is great!!!!!!!!!!!!!!
# 798                                       Mediocre food.
# 799    Once you get inside you'll be impressed with t...
# 800                                     I'm super pissd.
# 801                      And service was super friendly.
# 802    Why are these sad little vegetables so overcoo...
# 803                 This place was such a nice surprise!
# 804               They were golden-crispy and delicious.
# 805    I had high hopes for this place since the burg...
# 806    I could eat their bruschetta all day it is dev...
# 807    Not a single employee came out to see if we we...
# 808    Lastly, the mozzarella sticks, they were the b...
# 809    The first time I ever came here I had an amazi...
# 810    The server was very negligent of our needs and...
# 811                     The service was terrible though.
# 812    This place is overpriced, not consistent with ...
# 813                                      It was packed!!
# 814                                   I love this place.
# 815              I can say that the desserts were yummy.
# 816                               The food was terrible.
# 817      The seasonal fruit was fresh white peach puree.
# 818    It kept getting worse and worse so now I'm off...
# 819              This place should honestly be blown up.
# 820           But I definitely would not eat here again.
# 821                        Do not waste your money here!
# 822    I love that they put their food in nice plasti...
# 823           The crêpe was delicate and thin and moist.
# 824                                       Awful service.
# 825                            Won't ever go here again.
# 826                      Food quality has been horrible.
# 827    For that price I can think of a few place I wo...
# 828                    The service here is fair at best.
# 829    I do love sushi, but I found Kabuki to be over...
# 830    Do yourself a favor and stay away from this dish.
# 831                                   Very poor service.
# 832    No one at the table thought the food was above...
# 833    Best service and food ever, Maria our server w...
# 834                                 They were excellent.
# 835    I paid the bill but did not tip because I felt...
# 836      Just had lunch here and had a great experience.
# 837    I have never had such bland food which surpris...
# 838    Food is way overpriced and portions are fuckin...
# 839    I recently tried Caballero's and I have been b...
# 840    for 40 bucks a head, i really expect better food.
# 841                    The food came out at a good pace.
# 842    I ate there twice on my last visit, and especi...
# 843                                     I won't be back.
# 844     We could not believe how dirty the oysters were!
# 845                        This place deserves no stars.
# 846                    I would not recommend this place.
# 847    In fact I'm going to round up to 4 stars, just...
# 848    To my disbelief, each dish qualified as the wo...
# 849    Bad day or not, I have a very low tolerance fo...
# 850      the potatoes were great and so was the biscuit.
# 851                  I probably would not go here again.
# 852    So flavorful and has just the perfect amount o...
# 853    The price is reasonable and the service is great.
# 854    The Wife hated her meal (coconut shrimp), and ...
# 855    My fella got the huevos rancheros and they did...
# 856         Went in for happy hour, great list of wines.
# 857    Some may say this buffet is pricey but I think...
# 858                I probably won't be coming back here.
# 859              Worst food/service I've had in a while.
# 860    This place is pretty good, nice little vibe in...
# 861    Talk about great customer service of course we...
# 862    Hot dishes are not hot, cold dishes are close ...
# 863                  I love their fries and their beans.
# 864                  Always a pleasure dealing with him.
# 865    They have a plethora of salads and sandwiches,...
# 866    This place is awesome if you want something li...
# 867     For sushi on the Strip, this is the place to go.
# 868    The service was great, even the manager came a...
# 869    The feel of the dining room was more college c...
# 870    I started this review with two stars, but I'm ...
# 871    this is the worst sushi i have ever eat beside...
# 872    All in all an excellent restaurant highlighted...
# 873    My boyfriend and i sat at the bar and had a co...
# 874                              Weird vibe from owners.
# 875                           There was hardly any meat.
# 876       I've had better bagels from the grocery store.
# 877                               Go To Place for Gyros.
# 878    I love the owner/chef, his one authentic Japan...
# 879    Now the burgers aren't as good, the pizza whic...
# 880    I found a six inch long piece of wire in my sa...
# 881         The service was terrible, food was mediocre.
# 882                     We definately enjoyed ourselves.
# 883    I ordered Albondigas soup - which was just war...
# 884    On three different occasions I asked for well ...
# 885    I had about two bites and refused to eat anymore.
# 886                      The service was extremely slow.
# 887                After 20 minutes wait, I got a table.
# 888                     Seriously killer hot chai latte.
# 889    No allergy warnings on the menu, and the waitr...
# 890    My boyfriend tried the Mediterranean Chicken S...
# 891    Their rotating beers on tap is also a highligh...
# 892    Pricing is a bit of a concern at Mellow Mushroom.
# 893                                     Worst Thai ever.
# 894    If you stay in Vegas you must get breakfast he...
# 895    I want to first say our server was great and w...
# 896                       The pizza selections are good.
# 897                I had strawberry tea, which was good.
# 898    Highly unprofessional and rude to a loyal patron!
# 899                         Overall, a great experience.
# 900                          Spend your money elsewhere.
# 901    Their regular toasted bread was equally satisf...
# 902    The Buffet at Bellagio was far from what I ant...
# 903                     And the drinks are WEAK, people!
# 904                           -My order was not correct.
# 905    Also, I feel like the chips are bought, not ma...
# 906    After the disappointing dinner we went elsewhe...
# 907    The chips and sals a here is amazing!!!!!!!!!!...
# 908                               We won't be returning.
# 909                This is my new fav Vegas buffet spot.
# 910    I seriously cannot believe that the owner has ...
# 911                                      Very, very sad.
# 912    i felt insulted and disrespected, how could yo...
# 913    How can you call yourself a steakhouse if you ...
# 914      I'm not impressed with the concept or the food.
# 915    The only thing I wasn't too crazy about was th...
# 916    There is really nothing for me at postinos, ho...
# 917             I got food poisoning here at the buffet.
# 918    They brought a fresh batch of fries and I was ...
# 919    What SHOULD have been a hilarious, yummy Chris...
# 920    Needless to say, I won't be going back anytime...
# 921                            This place is disgusting!
# 922    Every time I eat here, I see caring teamwork t...
# 923                    The RI style calamari was a joke.
# 924    However, there was so much garlic in the fondu...
# 925    I could barely stomach the meal, but didn't co...
# 926    It was so bad, I had lost the heart to finish it.
# 927    It also took her forever to bring us the check...
# 928    We aren't ones to make a scene at restaurants ...
# 929                            Disappointing experience.
# 930    The food is about on par with Denny's, which i...
# 931    If you want to wait for mediocre food and down...
# 932     WAAAAAAyyyyyyyyyy over rated is all I am saying.
# 933                              We won't be going back.
# 934    The place was fairly clean but the food simply...
# 935                            This place lacked style!!
# 936    The sangria was about half of a glass wine ful...
# 937                            Don't bother coming here.
# 938    The meat was pretty dry, I had the sliced bris...
# 939    The building itself seems pretty neat, the bat...
# 940                                It was equally awful.
# 941                  Probably not in a hurry to go back.
# 942          very slow at seating even with reservation.
# 943          Not good by any stretch of the imagination.
# 944    The cashew cream sauce was bland and the veget...
# 945    The chipolte ranch dipping sause was tasteless...
# 946    It was a bit too sweet, not really spicy enoug...
# 947                            I was VERY disappointed!!
# 948           This place is horrible and way overpriced.
# 949    Maybe it's just their Vegetarian fare, but I'v...
# 950           It wasn't busy at all and now we know why.
# 951    The tables outside are also dirty a lot of the...
# 952    The ambiance here did not feel like a buffet s...
# 953                                 Con: spotty service.
# 954    The fries were not hot, and neither was my bur...
# 955                        But then they came back cold.
# 956       Then our food came out, disappointment ensued.
# 957              The real disappointment was our waiter.
# 958    My husband said she was very rude... did not e...
# 959    The only reason to eat here would be to fill u...
# 960    Insults, profound deuchebaggery, and had to go...
# 961    If someone orders two tacos don't' you think i...
# 962    She was quite disappointed although some blame...
# 963    After all the rave reviews I couldn't wait to ...
# 964    Del Taco is pretty nasty and should be avoided...
# 965            It's NOT hard to make a decent hamburger.
# 966                                 But I don't like it.
# 967                               Hell no will I go back
# 968    We've have gotten a much better service from t...
# 969    I don't know what the big deal is about this p...
# 970    I immediately said I wanted to talk to the man...
# 971                      The ambiance isn't much better.
# 972    Unfortunately, it only set us up for disapppoi...
# 973                                The food wasn't good.
# 974    Your servers suck, wait, correction, our serve...
# 975        What happened next was pretty....off putting.
# 976    too bad cause I know it's family owned, I real...
# 977                 Overpriced for what you are getting.
# 978                 I vomited in the bathroom mid lunch.
# 979    I kept looking at the time and it had soon bec...
# 980    I have been to very few places to eat that und...
# 981    We started with the tuna sashimi which was bro...
# 982                              Food was below average.
# 983    It sure does beat the nachos at the movies but...
# 984         All in all, Ha Long Bay was a bit of a flop.
# 985    The problem I have is that they charge $11.99 ...
# 986    Shrimp- When I unwrapped it (I live only 1/2 a...
# 987       It lacked flavor, seemed undercooked, and dry.
# 988    It really is impressive that the place hasn't ...
# 989    I would avoid this place if you are staying in...
# 990    The refried beans that came with my meal were ...
# 991           Spend your money and time some place else.
# 992    A lady at the table next to us found a live gr...
# 993              the presentation of the food was awful.
# 994             I can't tell you how disappointed I was.
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: Review, dtype: object

# %% [markdown]
# So, you've probably been able to find non-alphabetic characters (including punctuation), capitalized words (sometimes even whole reviews), and so on.
#
# #### Removing non-alphabetic chars
#
# Let's start by removing any non-alpha chars, using a regular expression. We'll create a separate corpus (a list of reviews), so that we leave the original dataset untouched.

# %%
import re

corpus = []
for i in range(0, dataset['Review'].size):
    # get review and remove non alpha chars
    review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
    # add review to corpus
    corpus.append(review)

print(corpus)
# Out:
# ['Wow    Loved this place ', 'Crust is not good ', 'Not tasty and the texture was just nasty ', 'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it ', 'The selection on the menu was great and so were the prices ', 'Now I am getting angry and I want my damn pho ', 'Honeslty it didn t taste THAT fresh  ', 'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer ', 'The fries were great too ', 'A great touch ', 'Service was very prompt ', 'Would not go back ', 'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced ', 'I tried the Cape Cod ravoli  chicken  with cranberry   mmmm ', 'I was disgusted because I was pretty sure that was human hair ', 'I was shocked because no signs indicate cash only ', 'Highly recommended ', 'Waitress was a little slow in service ', 'This place is not worth your time  let alone Vegas ', 'did not like at all ', 'The Burrittos Blah ', 'The food  amazing ', 'Service is also cute ', 'I could care less    The interior is just beautiful ', 'So they performed ', 'That s right    the red velvet cake     ohhh this stuff is so good ', '  They never brought a salad we asked for ', 'This hole in the wall has great Mexican street tacos  and friendly staff ', 'Took an hour to get our food only   tables in restaurant my food was Luke warm  Our sever was running around like he was totally overwhelmed ', 'The worst was the salmon sashimi ', 'Also there are combos like a burger  fries  and beer for    which is a decent deal ', 'This was like the final blow ', 'I found this place by accident and I could not be happier ', 'seems like a good quick place to grab a bite of some familiar pub food  but do yourself a favor and look elsewhere ', 'Overall  I like this place a lot ', 'The only redeeming quality of the restaurant was that it was very inexpensive ', 'Ample portions and good prices ', 'Poor service  the waiter made me feel like I was stupid every time he came to the table ', 'My first visit to Hiro was a delight ', 'Service sucks ', 'The shrimp tender and moist ', 'There is not a deal good enough that would drag me into that establishment again ', 'Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn t want to eat it for fear of getting sick ', 'On a positive note  our server was very attentive and provided great service ', 'Frozen pucks of disgust  with some of the worst people behind the register ', 'The only thing I did like was the prime rib and dessert section ', 'It s too bad the food is so damn generic ', 'The burger is good beef  cooked just right ', 'If you want a sandwich just go to any Firehouse     ', 'My side Greek salad with the Greek dressing was so tasty  and the pita and hummus was very refreshing ', 'We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside ', 'He came running after us when he realized my husband had left his sunglasses on the table ', 'Their chow mein is so good ', 'They have horrible attitudes towards customers  and talk down to each one when customers don t enjoy their food ', 'The portion was huge ', 'Loved it   friendly servers  great food  wonderful and imaginative menu ', 'The Heart Attack Grill in downtown Vegas is an absolutely flat lined excuse for a restaurant ', 'Not much seafood and like   strings of pasta at the bottom ', 'The salad had just the right amount of sauce to not over power the scallop  which was perfectly cooked ', 'The ripped banana was not only ripped  but petrified and tasteless ', 'At least think to refill my water before I struggle to wave you over for    minutes ', 'This place receives stars for their APPETIZERS   ', 'The cocktails are all handmade and delicious ', 'We d definitely go back here again ', 'We are so glad we found this place ', 'Great food and service  huge portions and they give a military discount ', 'Always a  ...

# %% [markdown]
# #### Lowercasing
#
# We can then apply lowercasing, so that words such as *Amazing*, *AMAZING* and *amazing* all have the same representation.

# %%
# your code here
corpus = list(map(lambda x: x.lower(), corpus))
print(corpus)
# Out:
# ['wow    loved this place ', 'crust is not good ', 'not tasty and the texture was just nasty ', 'stopped by during the late may bank holiday off rick steve recommendation and loved it ', 'the selection on the menu was great and so were the prices ', 'now i am getting angry and i want my damn pho ', 'honeslty it didn t taste that fresh  ', 'the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer ', 'the fries were great too ', 'a great touch ', 'service was very prompt ', 'would not go back ', 'the cashier had no care what so ever on what i had to say it still ended up being wayyy overpriced ', 'i tried the cape cod ravoli  chicken  with cranberry   mmmm ', 'i was disgusted because i was pretty sure that was human hair ', 'i was shocked because no signs indicate cash only ', 'highly recommended ', 'waitress was a little slow in service ', 'this place is not worth your time  let alone vegas ', 'did not like at all ', 'the burrittos blah ', 'the food  amazing ', 'service is also cute ', 'i could care less    the interior is just beautiful ', 'so they performed ', 'that s right    the red velvet cake     ohhh this stuff is so good ', '  they never brought a salad we asked for ', 'this hole in the wall has great mexican street tacos  and friendly staff ', 'took an hour to get our food only   tables in restaurant my food was luke warm  our sever was running around like he was totally overwhelmed ', 'the worst was the salmon sashimi ', 'also there are combos like a burger  fries  and beer for    which is a decent deal ', 'this was like the final blow ', 'i found this place by accident and i could not be happier ', 'seems like a good quick place to grab a bite of some familiar pub food  but do yourself a favor and look elsewhere ', 'overall  i like this place a lot ', 'the only redeeming quality of the restaurant was that it was very inexpensive ', 'ample portions and good prices ', 'poor service  the waiter made me feel like i was stupid every time he came to the table ', 'my first visit to hiro was a delight ', 'service sucks ', 'the shrimp tender and moist ', 'there is not a deal good enough that would drag me into that establishment again ', 'hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn t want to eat it for fear of getting sick ', 'on a positive note  our server was very attentive and provided great service ', 'frozen pucks of disgust  with some of the worst people behind the register ', 'the only thing i did like was the prime rib and dessert section ', 'it s too bad the food is so damn generic ', 'the burger is good beef  cooked just right ', 'if you want a sandwich just go to any firehouse     ', 'my side greek salad with the greek dressing was so tasty  and the pita and hummus was very refreshing ', 'we ordered the duck rare and it was pink and tender on the inside with a nice char on the outside ', 'he came running after us when he realized my husband had left his sunglasses on the table ', 'their chow mein is so good ', 'they have horrible attitudes towards customers  and talk down to each one when customers don t enjoy their food ', 'the portion was huge ', 'loved it   friendly servers  great food  wonderful and imaginative menu ', 'the heart attack grill in downtown vegas is an absolutely flat lined excuse for a restaurant ', 'not much seafood and like   strings of pasta at the bottom ', 'the salad had just the right amount of sauce to not over power the scallop  which was perfectly cooked ', 'the ripped banana was not only ripped  but petrified and tasteless ', 'at least think to refill my water before i struggle to wave you over for    minutes ', 'this place receives stars for their appetizers   ', 'the cocktails are all handmade and delicious ', 'we d definitely go back here again ', 'we are so glad we found this place ', 'great food and service  huge portions and they give a military discount ', 'always a  ...

# %% [markdown]
# #### Removing stop words
#
# Another common step which is sometimes applied is to remove any stop words (words that do not have domain semantics attached). We can use the stop words list provided in NLTK for English:

# %%
from nltk.corpus import stopwords

print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# Using this stop word list (which does include words that perhaps we should *not* remove, such as negation terms), we can considerably reduce the size of our corpus.

# %%
# your code here

# %% [markdown]
# This technique does not always enable machine learning classifiers to do better, as most of them are quite immune to the presence of stop words (which anyway tend not to be discriminative of the classes at hand). But in any case, removing stop words does reduce the size of the corpus.
#
# Can you check how smaller the corpus has become by removing stop words? (You might need to go back and get the size of the corpus *before* removing stop words, for comparison.)

# %%
# your code here

# %% [markdown]
# #### Stemming
#
# Finally, we can apply stemming to further reduce the size of the vocabulary through normalization.

# %%
# your code here

# %% [markdown]
# Can you check how much has the vocabulary been reduced by applying stemming? (You might need to go back one step and get the size of the vocabulary *before* applying stemming, for comparison.)

# %%
# your code here

# %% [markdown]
# #### Doing it all in one step
#
# Of course, instead of applying each of the aforementioned steps one at a time, it would be much more efficient to do it in a single loop. Here's the compact version for employing non-alphabetic filtering, lowercasing, stop word removal, and stemming.

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

corpus = []
ps = PorterStemmer()
for i in range(0, dataset['Review'].size):
    # get review and remove non alpha chars
    review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i])
    # to lower-case
    review = review.lower()
    # split into tokens, apply stemming and remove stop words
    review = ' '.join([ps.stem(w) for w in review.split() if not w in set(stopwords.words('english'))])
    corpus.append(review)

print(corpus)
# Out:
# ['wow love place', 'crust good', 'tasti textur nasti', 'stop late may bank holiday rick steve recommend love', 'select menu great price', 'get angri want damn pho', 'honeslti tast fresh', 'potato like rubber could tell made ahead time kept warmer', 'fri great', 'great touch', 'servic prompt', 'would go back', 'cashier care ever say still end wayyy overpr', 'tri cape cod ravoli chicken cranberri mmmm', 'disgust pretti sure human hair', 'shock sign indic cash', 'highli recommend', 'waitress littl slow servic', 'place worth time let alon vega', 'like', 'burritto blah', 'food amaz', 'servic also cute', 'could care less interior beauti', 'perform', 'right red velvet cake ohhh stuff good', 'never brought salad ask', 'hole wall great mexican street taco friendli staff', 'took hour get food tabl restaur food luke warm sever run around like total overwhelm', 'worst salmon sashimi', 'also combo like burger fri beer decent deal', 'like final blow', 'found place accid could happier', 'seem like good quick place grab bite familiar pub food favor look elsewher', 'overal like place lot', 'redeem qualiti restaur inexpens', 'ampl portion good price', 'poor servic waiter made feel like stupid everi time came tabl', 'first visit hiro delight', 'servic suck', 'shrimp tender moist', 'deal good enough would drag establish', 'hard judg whether side good gross melt styrofoam want eat fear get sick', 'posit note server attent provid great servic', 'frozen puck disgust worst peopl behind regist', 'thing like prime rib dessert section', 'bad food damn gener', 'burger good beef cook right', 'want sandwich go firehous', 'side greek salad greek dress tasti pita hummu refresh', 'order duck rare pink tender insid nice char outsid', 'came run us realiz husband left sunglass tabl', 'chow mein good', 'horribl attitud toward custom talk one custom enjoy food', 'portion huge', 'love friendli server great food wonder imagin menu', 'heart attack grill downtown vega absolut flat line excus restaur', 'much seafood like string pasta bottom', 'salad right amount sauc power scallop perfectli cook', 'rip banana rip petrifi tasteless', 'least think refil water struggl wave minut', 'place receiv star appet', 'cocktail handmad delici', 'definit go back', 'glad found place', 'great food servic huge portion give militari discount', 'alway great time do gringo', 'updat went back second time still amaz', 'got food appar never heard salt batter fish chewi', 'great way finish great', 'deal includ tast drink jeff went beyond expect', 'realli realli good rice time', 'servic meh', 'took min get milkshak noth chocol milk', 'guess known place would suck insid excalibur use common sens', 'scallop dish quit appal valu well', 'time bad custom servic', 'sweet potato fri good season well', 'today second time lunch buffet pretti good', 'much good food vega feel cheat wast eat opportun go rice compani', 'come like experienc underwhelm relationship parti wait person ask break', 'walk place smell like old greas trap other eat', 'turkey roast beef bland', 'place', 'pan cake everyon rave tast like sugari disast tailor palat six year old', 'love pho spring roll oh yummi tri', 'poor batter meat ratio made chicken tender unsatisfi', 'say food amaz', 'omelet die', 'everyth fresh delici', 'summari larg disappoint dine experi', 'like realli sexi parti mouth outrag flirt hottest person parti', 'never hard rock casino never ever step forward', 'best breakfast buffet', 'say bye bye tip ladi', 'never go', 'back', 'food arriv quickli', 'good', 'side cafe serv realli good food', 'server fantast found wife love roast garlic bone marrow ad extra meal anoth marrow go', 'good thing waiter help kept bloddi mari come', 'best buffet town price cannot beat', 'love mussel cook wine reduct duck tender potato dish delici', 'one better buffet', 'went tigerlilli fantast afternoon', 'food delici bartend attent person got great deal', 'ambienc wonder music play', 'go back next trip', 'sooooo good', 'real sushi lover let h ...

# %% [markdown]
# #### Wordclouds
#
# A visually appealing way of observing words in a corpus is by showing wordclouds. In order to make a single wordcloud for the whole corpus, we can join all reviews together. We then pass it to [WordCloud](https://amueller.github.io/word_cloud/) to generate a wordcloud: it will automatically assign weights to words based on the number of occurrences of each word.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud().generate(" ".join(corpus))

plt.figure()
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# It would also be interesting to visualize a wordcloud for each of the classes. Can you do it?

# %%
# your code here

# %% [markdown]
# ## Generating a data set
#
# We need to transform the data in the reduced-vocabulary corpus into a dataset that can be handled by machine learning models. Each review in our corpus is still rather unstructured: it is simply a lists of tokens. We will transform each review into a representation that makes use of the same set of features for the whole dataset.

# %% [markdown]
# #### Obtaining features from the Bag-of-Words model
#
# The simplest way to do it is to create a *bag-of-words* model, which ignores word sequence.
#
# We can use scikit-learn's [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html), which converts a collection of text documents to a matrix of token counts.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(corpus).toarray()

print(X.shape)

# %% [markdown]
# By using CountVectorizer, we can limit the number of features by using the *max_features* parameter.
#
# Let's look at the features we've got:

# %%
print(vectorizer.get_feature_names())

# %% [markdown]
# Each review is now represented as a vector with the number of occurrences for each of the features, indicating how many times the corresponding token appears in the review. Each vector is very sparse.
#
# Compare the contents of the 124th review with its representation vector following the bag-of-words model.

# %%
# your code here

# %% [markdown]
# #### Obtaining the classes
#
# We can get the target labels from the second column in our original dataset, after which we have the full table of data on which we can train machine learning algorithms that are able to classify restaurant reviews into either positive or negative.

# %%
y = dataset['Liked']

print(X.shape, y.shape)

# %% [markdown]
# ## Training classifiers
#
# To train machine learning classifiers, we first split the data into training and test sets.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

print("\nLabel distribution in the training set:")
print(y_train.value_counts())

print("\nLabel distribution in the test set:")
print(y_test.value_counts())

# %% [markdown]
# Every time you perform the train-test split, you get slightly different results in terms of class distribution. To avoid it, you can use the *random_state* parameter for *train_test_split* (e.g. *random_state = 0*), which ensures you always get the same exact split.
#
# You can also force a stratified split via parameter *stratify*, which ensures the same label distribution for both the training and test sets (*stratify=y*).

# %% [markdown]
# #### Naive Bayes
#
# We can start by trying out fitting a [Naive Bayes](https://scikit-learn.org/stable/modules/naive_bayes.html) classifier to our training data. For text data, the two most effective variants are [MultinomialNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html) and [ComplementNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.ComplementNB.html).

# %%
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB()
clf.fit(X_train, y_train)

# %% [markdown]
# Let's see the model's output on the test set:

# %%
y_pred = clf.predict(X_test)
print(y_pred)

# %% [markdown]
# We can assess the performance of the model by looking at different metrics.
#
# We can print the *confusion matrix*, and get scores for *accuracy*, *precision*, *recall*, and *f1*. Since our dataset is perfectly balanced, accuracy will be a fairly good indicator of performance.

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# confusion matrix
print(confusion_matrix(y_test, y_pred))

# accuracy, precision, recall, f1
# your code here

# %% [markdown]
# Let's do a test on a review obtained from the user. We ask the user for input, preprocess the inserted review by removing non-alphabetic characters and by applying lowercasing and stemming
#
# We then vectorize the review using the same vectorizer we've used before for creating the dataset. Note that we do not need to remove stop words, as these will be ignored by the vectorizer, since they do not show up in the feature set used to represent reviews.

# %%
import os

rev = input("Enter review: ")

# remove non alpha chars, apply lowercasing
# your code here


# split into tokens and apply stemming
# your code here


# vectorize the review
V = vectorizer.transform([rev]).toarray()

print(rev)
print(V.shape)
print(V)

if(clf.predict(V) == [1]):
    print('positive review (+)')
else:
    print('negative review (-)')

# %% [markdown]
# Many classifiers also provide probabilities for each possible class when making predictions. We can get them by using *predict_proba* instead of *predict*:

# %%
print(clf.predict(V))
print(clf.predict_proba(V))

# %% [markdown]
# #### Other classifiers
#
# Try out using other classifiers, such as:
# - *Logistic Regression*, through scikit-learn's [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) class.
# - *Decision Tree*, through scikit-learn's [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html) class. This model always assigns a probability of 1 to one of the classes.
# - *Random Forest*, through scikit-learn's [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) class.
# - *Support Vector Machines (SVM)*, through scikit-learn's [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) class. The SVM model also allows you to get probabilities, but for that you need to use the *probability=True* parameter setting in its constructor.
# - *Perceptron*, through scikit-learn's [Perceptron](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Perceptron.html) class. This model does not allow you to get probabilities.
# - *eXtreme Gradient Boosting*, through [XGBoost](https://xgboost.readthedocs.io/en/stable/).

# %%
# your code here

# %% [markdown]
# #### Cross-validation
#
# When addressing datasets that are not big enough, cross-validation allows us to use the whole dataset for both training and testing, by splitting the data into *k* folds. By training the model *k* times, each time using *k-1* folds and testing in the remaining fold, we can get performance scores for the model that are averaged accross the *k* iterations.

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

clf = SVC()
scores = cross_val_score(clf, X, y, cv=10)

print(scores)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))

# %% [markdown]
# The [cross_validate](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_validate.html) class allows greated flexibility in terms of the metrics we can get, and also provides train scores, fit times and score times.

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(clf, X, y, scoring=['accuracy', 'precision_macro', 'recall_macro', 'f1_macro'], return_train_score=True)
scores

# %% [markdown]
# ## Beyond bag-of-words
#
# We can use other forms of representing the text in our dataset. For instance, we can compute the occurrence of words in a different way. And we can consider features beyond simple words.

# %% [markdown]
# #### 1-hot vectors
#
# [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) includes a parameter (*binary*) that allows us to represent each review as a 1-hot vector with a 0 or a 1 for each of the features, indicating whether the corresponding token appears in the review.
#
# Can you try it out? Compare the previous representation vector of the 124th review with its 1-hot representation vector.

# %%
# your code here

# %% [markdown]
# #### TF-IDF
#
# We can adjust the counts of each word in a document by considering how many times it occurs in the document (its *term frequency TF*) and in how many documents it occurs (its *document frequency DF*). [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) provides a way to directly obtain TF-IDF weighted features: the term frequency of a word is multiplied by its *inverse* document frequency.
#
# Can you try it out? Compare the previous representation vector of the 124th review with its TF-IDF representation vector.

# %%
# your code here

# %% [markdown]
# Using TF-IDF weighing gives us a particularly interesting perspective on wordcloud visualizations. For that, we sum directly the values for each feature in the samples we want, and pass these values to [WordCloud](https://amueller.github.io/word_cloud/) as a python dict (containing each word and its frequency) using [generate_from_frequencies](https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html). Can you do it?

# %%
# your code here

# %% [markdown]
# #### N-grams
#
# The bag-of-words model is very simplistic and ignores word order. Perhaps we can do better if we make use of a bi-gram representation: generate features corresponding to pairs of consecutive tokens. Hopefully, in some cases we will be able to distinguish negations, such as in *not expensive* vs *expensive*.
#
# [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) (and also [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html)) includes the *ngram_range* parameter, which we can use to define the range of n-grams we want to generate as features. If we use a range (1,2), for instance, we'll get both individual tokens as well as bi-grams. Perhaps when doing so it will be a good idea not to get rid of stop words, since the stop word list we have used before includes negation tokens.
#
# Can you try it out?

# %%
# your code here
